# %% [markdown]
# # MNIST Diffusion Model

# %%
import torch

from torch_geometry.riemannian.prob_geodesics import ProbGEORCE, ProbEuclideanGEORCE
from torch_geometry.riemannian.prob_geodesics import TorchOptimization, TorchEuclideanOptimization
from torch_geometry.riemannian.manifolds import nSphere

# %%
import torch

from mnist_diffusion.model import MNISTDiffusion
from mnist_diffusion.train_mnist import create_mnist_dataloaders

# %%
model = MNISTDiffusion(timesteps=1000,
                image_size=28,
                in_channels=1,
                base_dim=64,
                dim_mults=[2,4]).to("cpu")

# %%
PATH = 'mnist_diffusion/results/steps_00046900.pt'

# %%
checkpoint = torch.load(PATH, weights_only=False, map_location=torch.device('cpu'))

# %%
model.load_state_dict(checkpoint['model'])
model.eval()
# Out:
# MNISTDiffusion(
#   (model): Unet(
#     (init_conv): ConvBnSiLu(
#       (module): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#     )
#     (time_embedding): Embedding(1000, 256)
#     (encoder_blocks): ModuleList(
#       (0): EncoderBlock(
#         (conv0): Sequential(
#           (0): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (1): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (2): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (3): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#         )
#         (time_mlp): TimeMLP(
#           (mlp): Sequential(
#             (0): Linear(in_features=256, out_features=128, bias=True)
#             (1): SiLU()
#             (2): Linear(in_features=128, out_features=64, bias=True)
#           )
#           (act): SiLU()
#         )
#         (conv1): ResidualDownsample(
#           (branch1): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (branch2): Sequential(
#             (0): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#             (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (channel_shuffle): ChannelShuffle()
#         )
#       )
#       (1): EncoderBlock(
#         (conv0): Sequential(
#           (0): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (1): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (2): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (3): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#         )
#         (time_mlp): TimeMLP(
#           (mlp): Sequential(
#             (0): Linear(in_features=256, out_features=256, bias=True)
#             (1): SiLU()
#             (2): Linear(in_features=256, out_features=128, bias=True)
#           )
#           (act): SiLU()
#         )
#         (conv1): ResidualDownsample(
#           (branch1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (branch2): Sequential(
#             (0): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#             (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (channel_shuffle): ChannelShuffle()
#         )
#       )
#     )
#     (decoder_blocks): ModuleList(
#       (0): DecoderBlock(
#         (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#         (conv0): Sequential(
#           (0): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#               (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (1): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#               (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (2): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#               (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (3): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#               (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#         )
#         (time_mlp): TimeMLP(
#           (mlp): Sequential(
#             (0): Linear(in_features=256, out_features=256, bias=True)
#             (1): SiLU()
#             (2): Linear(in_features=256, out_features=128, bias=True)
#           )
#           (act): SiLU()
#         )
#         (conv1): ResidualBottleneck(
#           (branch1): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (branch2): Sequential(
#             (0): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#             (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (channel_shuffle): ChannelShuffle()
#         )
#       )
#       (1): DecoderBlock(
#         (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#         (conv0): Sequential(
#           (0): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (1): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (2): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#           (3): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#         )
#         (time_mlp): TimeMLP(
#           (mlp): Sequential(
#             (0): Linear(in_features=256, out_features=128, bias=True)
#             (1): SiLU()
#             (2): Linear(in_features=128, out_features=64, bias=True)
#           )
#           (act): SiLU()
#         )
#         (conv1): ResidualBottleneck(
#           (branch1): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (branch2): Sequential(
#             (0): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#             (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (channel_shuffle): ChannelShuffle()
#         )
#       )
#     )
#     (mid_block): Sequential(
#       (0): ResidualBottleneck(
#         (branch1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ConvBnSiLu(
#             (module): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#         )
#         (branch2): Sequential(
#           (0): ConvBnSiLu(
#             (module): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ConvBnSiLu(
#             (module): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#         )
#         (channel_shuffle): ChannelShuffle()
#       )
#       (1): ResidualBottleneck(
#         (branch1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ConvBnSiLu(
#             (module): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#         )
#         (branch2): Sequential(
#           (0): ConvBnSiLu(
#             (module): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ConvBnSiLu(
#             (module): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#         )
#         (channel_shuffle): ChannelShuffle()
#       )
#       (2): ResidualBottleneck(
#         (branch1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ConvBnSiLu(
#             (module): Sequential(
#               (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#         )
#         (branch2): Sequential(
#           (0): ConvBnSiLu(
#             (module): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ConvBnSiLu(
#             (module): Sequential(
#               (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#         )
#         (channel_shuffle): ChannelShuffle()
#       )
#     )
#     (final_conv): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
train_dataloader,test_dataloader=create_mnist_dataloaders(batch_size=64,image_size=28)

# %%
for j,(image,target) in enumerate(train_dataloader):
    break

# %%
torch.randint(0,1000,(image.shape[0],))
# Out:
# tensor([170, 158, 997, 279, 447, 579,  77, 721, 649,  10, 508, 894, 378, 458,
#         537, 932, 966, 672, 619,  65, 327, 538, 707, 857, 213, 527, 272, 224,
#         777,   2, 232, 692, 138, 424, 439, 195, 497, 873, 498, 787, 124, 541,
#          40, 224, 250, 803, 180,  34, 922, 360, 320, 338, 256, 273,  88, 276,
#         388,  22, 913,  52, 979, 777, 382, 552])

# %%
model.model(image, torch.ones(64, dtype=torch.int64)).shape
# Out:
# torch.Size([64, 1, 28, 28])

# %%
model.model(image, torch.ones(64, dtype=torch.int64))
# Out:
# tensor([[[[ 0.0490, -0.0127,  0.0022,  ..., -0.0024, -0.0187,  0.0578],
#           [-0.0009, -0.0671, -0.0651,  ..., -0.0522, -0.0566, -0.0089],
#           [-0.0112, -0.0426, -0.0456,  ..., -0.0584, -0.0813, -0.0304],
#           ...,
#           [-0.0073, -0.0377, -0.0508,  ..., -0.0505, -0.0568, -0.0021],
#           [ 0.0314, -0.0417, -0.0388,  ..., -0.0664, -0.0681, -0.0302],
#           [ 0.0218, -0.0510, -0.0450,  ..., -0.0582, -0.0120,  0.0468]]],
#
#
#         [[[ 0.0510, -0.0099,  0.0045,  ..., -0.0061, -0.0228,  0.0488],
#           [ 0.0011, -0.0643, -0.0599,  ..., -0.0527, -0.0569, -0.0098],
#           [-0.0110, -0.0406, -0.0401,  ..., -0.0541, -0.0756, -0.0270],
#           ...,
#           [-0.0069, -0.0480, -0.0467,  ..., -0.0482, -0.0568, -0.0061],
#           [ 0.0340, -0.0434, -0.0442,  ..., -0.0637, -0.0696, -0.0356],
#           [ 0.0353, -0.0494, -0.0450,  ..., -0.0560, -0.0140,  0.0470]]],
#
#
#         [[[ 0.0464, -0.0104,  0.0053,  ..., -0.0050, -0.0151,  0.0634],
#           [ 0.0007, -0.0641, -0.0590,  ..., -0.0475, -0.0537, -0.0133],
#           [-0.0104, -0.0402, -0.0413,  ..., -0.0503, -0.0759, -0.0302],
#           ...,
#           [-0.0018, -0.0367, -0.0513,  ..., -0.0491, -0.0550, -0.0097],
#           [ 0.0313, -0.0421, -0.0404,  ..., -0.0654, -0.0683, -0.0373],
#           [ 0.0246, -0.0497, -0.0456,  ..., -0.0500, -0.0097,  0.0448]]],
#
#
#         ...,
#
#
#         [[[ 0.0497, -0.0102,  0.0034,  ..., -0.0089, -0.0123,  0.0542],
#           [ 0.0023, -0.0651, -0.0614,  ..., -0.0452, -0.0493, -0.0095],
#           [-0.0095, -0.0413, -0.0430,  ..., -0.0473, -0.0740, -0.0281],
#           ...,
#           [-0.0061, -0.0412, -0.0546,  ..., -0.0504, -0.0536, -0.0043],
#           [ 0.0271, -0.0445, -0.0425,  ..., -0.0640, -0.0646, -0.0352],
#           [ 0.0146, -0.0488, -0.0467,  ..., -0.0535, -0.0123,  0.0505]]],
#
#
#         [[[ 0.0480, -0.0103,  0.0042,  ..., -0.0055, -0.0219,  0.0562],
#           [ 0.0019, -0.0646, -0.0614,  ..., -0.0479, -0.0520, -0.0061],
#           [-0.0100, -0.0403, -0.0420,  ..., -0.0529, -0.0758, -0.0251],
#           ...,
#           [-0.0025, -0.0414, -0.0551,  ..., -0.0479, -0.0565, -0.0055],
#           [ 0.0284, -0.0455, -0.0423,  ..., -0.0627, -0.0693, -0.0354],
#           [ 0.0227, -0.0536, -0.0464,  ..., -0.0543, -0.0134,  0.0460]]],
#
#
#         [[[ 0.0458, -0.0102,  0.0024,  ..., -0.0056, -0.0155,  0.0577],
#           [ 0.0020, -0.0651, -0.0622,  ..., -0.0453, -0.0491, -0.0107],
#           [-0.0101, -0.0410, -0.0438,  ..., -0.0463, -0.0696, -0.0264],
#           ...,
#           [-0.0047, -0.0398, -0.0551,  ..., -0.0490, -0.0532, -0.0054],
#           [ 0.0272, -0.0437, -0.0437,  ..., -0.0640, -0.0654, -0.0342],
#           [ 0.0162, -0.0500, -0.0462,  ..., -0.0532, -0.0108,  0.0455]]]],
#        grad_fn=<ConvolutionBackward0>)

# %%
model.model(image[0].reshape(1,1,28,28), torch.ones(1, dtype=torch.int64)).shape
# Out:
# torch.Size([1, 1, 28, 28])

# %%
betas=model._cosine_variance_schedule(1000)
alphas=1.-betas
alphas_cumprod=torch.cumprod(alphas,dim=-1)

# %%
t0 = 1
alphas_cumprod[t0]
# Out:
# tensor(0.9999)

# %%
def score_fun(x,t):
    
    x = x.reshape(-1,1,28,28)
    
    eps = model.model(x.reshape(-1,1,28,28), t*torch.ones(x.shape[0], dtype=torch.int64)).reshape(-1)
    den = torch.sqrt(1-alphas_cumprod[t])
                   
    return -eps/den

# %%
score_fun(image[0], 1)
# Out:
# tensor([-5.2466e+00,  1.3559e+00, -2.3872e-01,  9.4982e-01,  2.1236e+00,
#          9.1434e-01,  9.1391e-01,  9.0392e-01,  9.2279e-01,  1.0896e+00,
#          6.8778e-01, -1.1119e-01, -1.1489e-01,  9.0330e-01,  1.2162e+00,
#          2.1092e-01,  3.1610e-01,  1.2393e+00,  1.3019e+00,  5.3153e-01,
#          9.1160e-04,  5.7810e-01,  1.3236e+00,  8.8487e-01,  5.4321e-01,
#          2.6083e-01,  2.0037e+00, -6.1825e+00,  9.2888e-02,  7.1732e+00,
#          6.9674e+00,  6.0441e+00,  5.9747e+00,  5.0643e+00,  5.3609e+00,
#          5.6323e+00,  5.6096e+00,  5.5566e+00,  6.3704e+00,  5.8165e+00,
#          5.1250e+00,  4.7669e+00,  5.4468e+00,  5.6668e+00,  6.0897e+00,
#          7.1207e+00,  6.1834e+00,  5.0942e+00,  5.5249e+00,  5.8868e+00,
#          7.9299e+00,  5.9548e+00,  4.7574e+00,  5.6342e+00,  6.0019e+00,
#          5.4069e+00,  6.0779e+00,  2.2861e-01, -3.3572e+00,  4.4628e+00,
#          4.1523e+00,  6.9996e+00,  5.5824e+00,  5.6895e+00,  5.7903e+00,
#          5.9170e+00,  6.0591e+00,  6.0599e+00,  5.8581e+00,  5.3739e+00,
#          7.0584e+00,  7.1364e+00,  4.6982e+00,  3.8557e+00, -9.2325e-01,
#         -4.6738e-01,  1.7774e+00,  8.8918e+00,  6.3294e+00,  5.7976e+00,
#          5.8863e+00,  6.1652e+00,  7.3743e+00,  7.1041e+00,  7.2807e+00,
#          3.2299e+00, -2.3312e+00,  5.4608e+00,  4.8151e+00,  1.0973e+00,
#          4.4194e+00,  3.9419e+00,  4.0730e+00,  3.6891e+00,  3.5385e+00,
#          4.1310e+00,  4.4042e+00,  3.7358e+00,  3.4878e+00,  3.7671e+00,
#          6.9963e-01,  5.7437e+00,  2.6844e-01, -2.6403e-02,  4.3104e+00,
#          5.3520e+00,  4.7562e+00,  4.3181e+00,  3.6824e+00,  3.4003e+00,
#          2.7375e+00,  6.2278e+00,  1.2864e+00, -5.0044e+00],
#        grad_fn=<DivBackward0>)

# %%
init_val = torch.normal(torch.zeros((99,784)), torch.ones(784))

# %%
init_val.shape
# Out:
# torch.Size([99, 784])

# %%
t0 = 0.01
M_ProbGEORCE = ProbEuclideanGEORCE(score_fun = lambda z: score_fun(z,1),#lambda z: score_fun(z,t0),
                                    init_fun=None,#lambda *args: init_val,#None,
                                    lam=10.0,#,t0**4,
                                    T=100,
                                    max_iter=100,
                                    line_search_params={'rho': 0.1, 'max_iter': 100},
                                   )

# %%
t0 = 0.01
M_ProbTorch = TorchEuclideanOptimization(score_fun = lambda z: score_fun(z,1),#lambda z: score_fun(z,t0),
                                        init_fun=None,#lambda *args: init_val,#None,
                                        lam=50.0,#,t0**4,
                                        T=100,
                                        max_iter=1000,
                                       )

# %%
z0 = image[0].reshape(-1).detach()
zT = image[1].reshape(-1).detach()

# %%
#jit_Geo = torch.compile(M_ProbGeodesic)

# %%
test = M_ProbTorch(z0, zT)
# Out:
# 0
# 273.7106018066406
# 1
# 3472.613525390625
# 2
# 318.4455871582031
# 3
# 849.9356689453125
# 4
# 1958.421630859375
# 5
# 1380.7667236328125
# 6
# 355.707763671875
# 7
# 104.05157470703125
# 8
# 621.339599609375
# 9
# 1000.5736083984375
# 10
# 797.0107421875
# 11
# 315.8206481933594
# 12
# 62.9185676574707
# 13
# 213.21046447753906
# 14
# 482.2017822265625
# 15
# 529.6819458007812
# 16
# 328.65972900390625
# 17
# 107.50538635253906
# 18
# 70.3865737915039
# 19
# 196.32847595214844
# 20
# 303.3755798339844
# 21
# 269.3908996582031
# 22
# 141.2621307373047
# 23
# 54.522010803222656
# 24
# 78.97319030761719
# 25
# 154.71786499023438
# 26
# 179.73440551757812
# 27
# 127.78521728515625
# 28
# 61.441715240478516
# 29
# 47.57952880859375
# 30
# 82.86078643798828
# 31
# 110.93099975585938
# 32
# 95.72242736816406
# 33
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_119336/1707000583.py in <module>
# ----> 1 test2 = M_ProbGeodesic(z0, zT)
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/torch_geometry/riemannian/prob_geodesics/prob_georce.py in __call__(self, z0, zT, step)
#     425             print(idx)
#     426             while self.cond_fun(grad_norm, idx):
# --> 427                 zt, ut, gt, grad_norm, idx = self.georce_step(zt, ut, gt, grad_norm, idx)
#     428                 print(idx)
#     429         elif step == "for":
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/torch_geometry/riemannian/prob_geodesics/prob_georce.py in georce_step(self, zt, ut, gt, grad_norm, idx)
#     383
#     384         ut_hat = self.update_ut(gt)
# --> 385         tau = self.line_search(zt, ut_hat, ut)
#     386
#     387         ut = tau*ut_hat+(1.-tau)*ut
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/torch_geometry/line_search/backtracking.py in __call__(self, x, *args)
#     160
#     161         alpha, idx = self.alpha, 0
# --> 162         while self.cond_fun(alpha, idx, *args):
#     163             alpha, idx = self.update_alpha(alpha, idx)
#     164
#
# ~/anaconda3/lib/python3.9/site-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/torch_geometry/line_search/backtracking.py in cond_fun(self, alpha, idx, *args)
#     136
#     137         x_new = self.update_fun(self.x, alpha, *args)
# --> 138         obj = self.obj_fun(x_new, *args)
#     139         bool_val = self.condition(x_new, obj, alpha, *args)
#     140
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/torch_geometry/riemannian/prob_geodesics/prob_georce.py in reg_energy(self, zt, *args)
#     311                    )->Tensor:
#     312
# --> 313         score_norm2 = self.score_norm2(zt)
#     314         energy = self.energy(zt)
#     315
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/torch_geometry/riemannian/prob_geodesics/prob_georce.py in score_norm2(self, zt)
#     292                     )->Tensor:
#     293
# --> 294         score = self.score_fun(zt)
#     295         score_norm2 = torch.sum(score**2)
#     296
#
# /tmp/ipykernel_119336/2736355792.py in <lambda>(z)
#       1 t0 = 0.01
# ----> 2 M_ProbGeodesic = ProbEuclideanGEORCE(score_fun = lambda z: score_fun(z,1),#lambda z: score_fun(z,t0),
#       3                                     init_fun=lambda *args: test[0][1:-1],#None,
#       4                                     lam=50.0,#,t0**4,
#       5                                     T=100,
#
# /tmp/ipykernel_119336/1150565344.py in score_fun(x, t)
#       3     x = x.reshape(-1,1,28,28)
#       4
# ----> 5     eps = model.model(x.reshape(-1,1,28,28), t*torch.ones(x.shape[0], dtype=torch.int64)).reshape(-1)
#       6     den = torch.sqrt(1-alphas_cumprod[t])
#       7
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/mnist_diffusion/unet.py in forward(self, x, t)
#     148         encoder_shortcuts=[]
#     149         for encoder_block in self.encoder_blocks:
# --> 150             x,x_shortcut=encoder_block(x,t)
#     151             encoder_shortcuts.append(x_shortcut)
#     152         x=self.mid_block(x)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/mnist_diffusion/unet.py in forward(self, x, t)
#      96         if t is not None:
#      97             x=self.time_mlp(x_shortcut,t)
# ---> 98         x=self.conv1(x)
#      99
#     100         return [x,x_shortcut]
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/mnist_diffusion/unet.py in forward(self, x)
#      62
#      63     def forward(self,x):
# ---> 64         x=torch.cat([self.branch1(x),self.branch2(x)],dim=1)
#      65         x=self.channel_shuffle(x) #shuffle two branches
#      66
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     217     def forward(self, input):
#     218         for module in self:
# --> 219             input = module(input)
#     220         return input
#     221
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# ~/PhD/Projects/prob_geodesics/prob_geodesics/mnist_diffusion/unet.py in forward(self, x)
#      21                                   nn.SiLU(inplace=True))
#      22     def forward(self,x):
# ---> 23         return self.module(x)
#      24
#      25 class ResidualBottleneck(nn.Module):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     217     def forward(self, input):
#     218         for module in self:
# --> 219             input = module(input)
#     220         return input
#     221
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     456
#     457     def forward(self, input: Tensor) -> Tensor:
# --> 458         return self._conv_forward(input, self.weight, self.bias)
#     459
#     460 class Conv3d(_ConvNd):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     452                             weight, bias, self.stride,
#     453                             _pair(0), self.dilation, self.groups)
# --> 454         return F.conv2d(input, weight, bias, self.stride,
#     455                         self.padding, self.dilation, self.groups)
#     456
#
# KeyboardInterrupt:

# %%
test[-2]

# %%
test[1]
# Out:
# 11.744451522827148

# %%
torch.linalg.norm(test[0][1:-1]-init_curve)
# Out:
# tensor(17.5633)

# %%
import matplotlib.pyplot as plt
import torchvision.utils as vutils

img_height = 28+2
tick_list = [img_height/2+j*img_height for j in range(10)]
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.set_title(f"MNIST Geodesics")
ax.imshow(vutils.make_grid(test[0].reshape(-1,1,28,28)[::10], padding=2, normalize=True, nrow=10+1).permute(1, 2, 0))
ax.axes.get_xaxis().set_visible(False)
#ax.set_yticks(tick_list)
#ax.set_yticklabels(length)

fig.tight_layout()

plt.show()

# %%
t0 = 0.01
M_ProbGeodesic = ProbEuclideanGEORCE(score_fun = lambda z: score_fun(z,1),#lambda z: score_fun(z,t0),
                                    init_fun=None,
                                    lam=10.0,#,t0**4,
                                    T=100,
                                    max_iter=1,
                                    line_search_params={'rho': 0.5},
                                   )

# %%
test = M_ProbGeodesic(z0, zT)
# Out:
# 33.968379974365234
# 0
# 15
# 31.857494354248047
# 1

# %%
test[1]
# Out:
# 31.857494354248047

# %%
test[-2]
# Out:
# 64.57770538330078

# %%
test[0].shape
# Out:
# torch.Size([101, 784])

# %%
torch.linalg.norm(init_curve-test[0][1:-1])
# Out:
# tensor(1.5553)

# %%
import matplotlib.pyplot as plt
import torchvision.utils as vutils

img_height = 28+2
tick_list = [img_height/2+j*img_height for j in range(10)]
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.set_title(f"MNIST Geodesics")
ax.imshow(vutils.make_grid(test[0].reshape(-1,1,28,28)[::10], padding=2, normalize=True, nrow=10+1).permute(1, 2, 0))
ax.axes.get_xaxis().set_visible(False)
#ax.set_yticks(tick_list)
#ax.set_yticklabels(length)

fig.tight_layout()

plt.show()

# %%
init_curve = torch.linspace(0.,1.,100+1)[1:-1].reshape(-1,1)*(zT.reshape(-1)-z0.reshape(-1))+z0.reshape(-1)

# %%
import matplotlib.pyplot as plt
import torchvision.utils as vutils

img_height = 28+2
tick_list = [img_height/2+j*img_height for j in range(10)]
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.set_title(f"MNIST Geodesics")
ax.imshow(vutils.make_grid(init_curve.reshape(-1,1,28,28)[::10], padding=2, normalize=True, nrow=10+1).permute(1, 2, 0))
ax.axes.get_xaxis().set_visible(False)
#ax.set_yticks(tick_list)
#ax.set_yticklabels(length)

fig.tight_layout()

plt.show()
